# %%
import pandas as pd
import sqlite3
import os

# Load datasets
orders = pd.read_csv("../data/raw/olist_orders_dataset.csv")
items = pd.read_csv("../data/raw/olist_order_items_dataset.csv")
payments = pd.read_csv("../data/raw/olist_order_payments_dataset.csv")
reviews = pd.read_csv("../data/raw/olist_order_reviews_dataset.csv")
customers = pd.read_csv("../data/raw/olist_customers_dataset.csv")
products = pd.read_csv("../data/raw/olist_products_dataset.csv")
categories = pd.read_csv("../data/raw/product_category_name_translation.csv")

# ----------------------------
# Convert datetime columns
# ----------------------------
order_date_cols = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in order_date_cols:
    orders[col] = pd.to_datetime(orders[col], errors="coerce")

# ----------------------------
# Basic cleaning
# ----------------------------
items = items.drop_duplicates()
payments = payments.drop_duplicates()
reviews = reviews.drop_duplicates()
orders = orders.drop_duplicates()
customers = customers.drop_duplicates()
products = products.drop_duplicates()
categories = categories.drop_duplicates()

# Numeric casting
items["price"] = pd.to_numeric(items["price"], errors="coerce")
items["freight_value"] = pd.to_numeric(items["freight_value"], errors="coerce")
payments["payment_value"] = pd.to_numeric(payments["payment_value"], errors="coerce")

# ----------------------------
# Aggregate order-level tables before merging
# ----------------------------
payment_agg = (
    payments.groupby("order_id", as_index=False)
    .agg(
        total_payment_value=("payment_value", "sum"),
        payment_installments=("payment_installments", "max")
    )
)

review_agg = (
    reviews.groupby("order_id", as_index=False)
    .agg(
        review_score=("review_score", "mean")
    )
)

# ----------------------------
# Product category translation
# ----------------------------
products = products.merge(
    categories,
    on="product_category_name",
    how="left"
)

# ----------------------------
# Build cleaned item-level dataset
# ----------------------------
df = (
    items
    .merge(orders, on="order_id", how="left")
    .merge(customers, on="customer_id", how="left")
    .merge(products, on="product_id", how="left")
    .merge(payment_agg, on="order_id", how="left")
    .merge(review_agg, on="order_id", how="left")
)

# ----------------------------
# Feature engineering
# ----------------------------
df["revenue"] = df["price"] + df["freight_value"]

df["order_month"] = df["order_purchase_timestamp"].dt.to_period("M").astype(str)
df["order_year"] = df["order_purchase_timestamp"].dt.year
df["order_weekday"] = df["order_purchase_timestamp"].dt.day_name()

df["delivery_days"] = (
    df["order_delivered_customer_date"] - df["order_purchase_timestamp"]
).dt.days

df["estimated_delivery_days"] = (
    df["order_estimated_delivery_date"] - df["order_purchase_timestamp"]
).dt.days

df["delivery_delay_days"] = (
    df["order_delivered_customer_date"] - df["order_estimated_delivery_date"]
).dt.days

# ----------------------------
# Keep useful columns
# ----------------------------
keep_cols = [
    "order_id",
    "order_item_id",
    "product_id",
    "seller_id",
    "customer_id",
    "customer_unique_id",
    "customer_city",
    "customer_state",
    "order_status",
    "order_purchase_timestamp",
    "order_month",
    "order_year",
    "order_weekday",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "delivery_days",
    "delivery_delay_days",
    "price",
    "freight_value",
    "revenue",
    "payment_installments",
    "total_payment_value",
    "review_score",
    "product_category_name",
    "product_category_name_english"
]

df = df[keep_cols]

# ----------------------------
# Save cleaned CSV
# ----------------------------
os.makedirs("../data/processed", exist_ok=True)
df.to_csv("../data/processed/clean_olist_data.csv", index=False)

# ----------------------------
# Save to SQLite
# ----------------------------
conn = sqlite3.connect("../data/processed/olist_analysis.db")
df.to_sql("olist", conn, if_exists="replace", index=False)
conn.close()

print("Cleaned dataset saved to ../data/processed/clean_olist_data.csv")
print("SQLite database saved to ../data/processed/olist_analysis.db")
print(df.head())
print(df.shape)
# Out:
# Cleaned dataset saved to ../data/processed/clean_olist_data.csv
# SQLite database saved to ../data/processed/olist_analysis.db
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#                         customer_id                customer_unique_id  \
# ...
